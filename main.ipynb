# %% [markdown]
# # Germany Municipalities - Sample Notebook

# %% [markdown]
# ## Explore data

# %%
import pandas as pd        

# Read csv file
dataframe = pd.read_csv("./data/03-gold/germany-municipalities-2026-03-csv/germany-municipalities-2026-03-municipalities.csv")

# %%
# Display 5 first rows
dataframe.head()
# Out:
#            ars      ags          type                    sub_type  \
# 0  10010000000  1001000  municipality  independent_city_duplicate
# 1  10020000000  1002000  municipality  independent_city_duplicate
# 2  10030000000  1003000  municipality  independent_city_duplicate
# 3  10040000000  1004000  municipality  independent_city_duplicate
# 4  10510011011  1051011  municipality                        city
#
#         municipality_name  area_sqkm  population_total  population_male  \
# 0        Flensburg, Stadt      56.73             96326            47651
# 1  Kiel, Landeshauptstadt     118.65            252668           123532
# 2      Lübeck, Hansestadt     214.19            216889           104309
# 3       Neumünster, Stadt      71.66             79809            39742
# 4      Brunsbüttel, Stadt      65.21             12692             6419
#
#    population_female  population_per_sqkm  zip_code center_lon center_lat  \
# ...

# %%
# Display dataframe info
dataframe.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10943 entries, 0 to 10942
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ars                          10943 non-null  int64
#  1   ags                          10943 non-null  int64
#  2   type                         10943 non-null  str
#  3   sub_type                     10943 non-null  str
#  4   municipality_name            10943 non-null  str
#  5   area_sqkm                    10943 non-null  float64
#  6   population_total             10943 non-null  int64
#  7   population_male              10943 non-null  int64
#  8   population_female            10943 non-null  int64
#  9   population_per_sqkm          10943 non-null  int64
#  10  zip_code                     10751 non-null  float64
#  11  center_lon                   10940 non-null  str
#  12  center_lat                   10940 non-null  str
# ...

# %%
# Describe dataframe
dataframe.describe()
# Out:
#                 ars           ags     area_sqkm  population_total  \
# count  1.094300e+04  1.094300e+04  10943.000000      1.094300e+04
# mean   8.235411e+10  8.235133e+06     32.686096      7.637498e+03
# std    4.027390e+10  4.027441e+06     41.244369      5.018875e+04
# min    1.001000e+10  1.001000e+06      0.310000      0.000000e+00
# 25%    6.535000e+10  6.535002e+06      8.360000      6.190000e+02
# 50%    8.128014e+10  8.128047e+06     19.090000      1.750000e+03
# 75%    9.772019e+10  9.772150e+06     40.805000      5.489500e+03
# max    1.607751e+11  1.607705e+07    891.120000      3.685265e+06
#
#        population_male  population_female  population_per_sqkm      zip_code  \
# count     1.094300e+04       1.094300e+04         10943.000000  10751.000000
# mean      3.768775e+03       3.868723e+03           186.620488  52431.387964
# std       2.463676e+04       2.555349e+04           290.771239  29095.625813
# ...
