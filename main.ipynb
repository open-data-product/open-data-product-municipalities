# %% [markdown]
# # Municipalities - Sample Notebook

# %% [markdown]
# ## Explore data

# %%
import pandas as pd        

# Read csv file
dataframe = pd.read_csv("./data/03-gold/germany-municipalities-2026-03-csv/germany-municipalities-2026-03-ars.csv")

# %%
# Display 5 first rows
dataframe.head()
# Out:
#            ars          type                    sub_type  \
# 0  10010000000  municipality  independent_city_duplicate
# 1  10020000000  municipality  independent_city_duplicate
# 2  10030000000  municipality  independent_city_duplicate
# 3  10040000000  municipality  independent_city_duplicate
# 4  10510011011  municipality                        city
#
#         municipality_name  area_sqkm  population_total  population_male  \
# 0        Flensburg, Stadt      56.73             96326            47651
# 1  Kiel, Landeshauptstadt     118.65            252668           123532
# 2      Lübeck, Hansestadt     214.19            216889           104309
# 3       Neumünster, Stadt      71.66             79809            39742
# 4      Brunsbüttel, Stadt      65.21             12692             6419
#
#    population_female  population_per_sqkm  zip_code center_lon center_lat  \
# 0              48675                 1698   24937.0    9,43751   54,78252
# ...

# %%
# Display dataframe info
dataframe.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10943 entries, 0 to 10942
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ars                          10943 non-null  int64
#  1   type                         10943 non-null  str
#  2   sub_type                     10943 non-null  str
#  3   municipality_name            10943 non-null  str
#  4   area_sqkm                    10943 non-null  float64
#  5   population_total             10943 non-null  int64
#  6   population_male              10943 non-null  int64
#  7   population_female            10943 non-null  int64
#  8   population_per_sqkm          10943 non-null  int64
#  9   zip_code                     10751 non-null  float64
#  10  center_lon                   10940 non-null  str
#  11  center_lat                   10940 non-null  str
#  12  degree_of_urbanization_key   10942 non-null  float64
# ...

# %%
# Describe dataframe
dataframe.describe()
# Out:
#                 ars     area_sqkm  population_total  population_male  \
# count  1.094300e+04  10943.000000      1.094300e+04     1.094300e+04
# mean   8.235411e+10     32.686096      7.637498e+03     3.768775e+03
# std    4.027390e+10     41.244369      5.018875e+04     2.463676e+04
# min    1.001000e+10      0.310000      0.000000e+00     0.000000e+00
# 25%    6.535000e+10      8.360000      6.190000e+02     3.100000e+02
# 50%    8.128014e+10     19.090000      1.750000e+03     8.790000e+02
# 75%    9.772019e+10     40.805000      5.489500e+03     2.726500e+03
# max    1.607751e+11    891.120000      3.685265e+06     1.810259e+06
#
#        population_female  population_per_sqkm      zip_code  \
# count       1.094300e+04         10943.000000  10751.000000
# mean        3.868723e+03           186.620488  52431.387964
# std         2.555349e+04           290.771239  29095.625813
# min         0.000000e+00             0.000000   1067.000000
# ...
